# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os, json, math, time
from yelpapi import YelpAPI
from tqdm.notebook import tqdm_notebook

# %%
with open("/Users/carlo/.secret/yelp_api.json", 'r') as f:
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
yelp = YelpAPI(login['api-key'], timeout_s=5.0)

# %%
location = 'Los Angeles, CA 90027'
term = 'italian'

# %%
location.split(',')[0]
# Out:
# 'Los Angeles'

# %%
FOLDER = 'Data/'
os.makedirs(FOLDER, exist_ok=True)

JSON_FILE = FOLDER+f"{location.split(',')[0]}-{term}.json"
JSON_FILE
# Out:
# 'Data/Los Angeles-italian.json'

# %%
file_exists = os.path.isfile(JSON_FILE)
if file_exists == False:
    folder = os.path.dirname(JSON_FILE)
    if len(folder)>0:
        os.makedirs(folder, exist_ok=True)
    print(f"[i] {JSON_FILE} not found. Saving empty list to file.")
    with open(JSON_FILE, 'w') as f:
        json.dump([], f)
else:
    print(f"[i] {JSON_FILE} already exists.")
# Out:
# [i] Data/Los Angeles-italian.json not found. Saving empty list to file.

# %%
results = yelp.search_query(term=term, location=location)
type(results)
# Out:
# dict

# %%
len(results)
# Out:
# 3

# %%
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
results['total']
# Out:
# 1100

# %%
results['region']
# Out:
# {'center': {'longitude': -118.28910827636719, 'latitude': 34.12827883313062}}

# %%
results['businesses']
# Out:
# [{'id': '-KqNRM-drDM7Nu9i9xEnfA',
#   'alias': 'la-pergoletta-los-angeles-4',
#   'name': 'La Pergoletta',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/G1XjeBOpUByZsPHFFiNFgQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/la-pergoletta-los-angeles-4?adjust_creative=mXw-LHOZWkYoDBfSh2oMDQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=mXw-LHOZWkYoDBfSh2oMDQ',
#   'review_count': 1346,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 34.1037812, 'longitude': -118.2872479},
#   'transactions': ['restaurant_reservation', 'pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1802 Hillhurst Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Los Angeles',
#    'zip_code': '90027',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1802 Hillhurst Ave', 'Los Angeles, CA 90027']},
#   'phone': '+13236648259',
#   'display_phone': '(323) 664-8259',
#   'distance': 2730.5910102979096},
#  {'id': 'IMvn6wIq4YvJ9Mk5rqdX8g',
#   'alias': 'spina-los-angeles',
#   'name': 'Spina',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GO39QCvnbuUdf__CT72U3g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/spina-los-angeles?adjust_creative=mXw-LHOZWkYoDBfSh2oMDQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=mXw-LHOZWkYoDBfSh2oMDQ',
#   'review_count': 13,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'desserts', 'title': 'Desserts'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 34.11792, 'longitude': -118.26131},
#   'transactions': [],
#   'location': {'address1': '3193 Glendale Blvd',
#    'address2': '',
#    'address3': None,
#    'city': 'Los Angeles',
#    'zip_code': '90039',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['3193 Glendale Blvd', 'Los Angeles, CA 90039']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 2803.7303893754183},
#  {'id': 'WylKsZv1qKCDqrHd-joiOA',
#   'alias': 'michelangelo-ristorante-los-angeles-2',
#   'name': 'Michelangelo Ristorante',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZRopJJQMlTtxYvw09T2BIw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/michelangelo-ristorante-los-angeles-2?adjust_creative=mXw-LHOZWkYoDBfSh2oMDQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=mXw-LHOZWkYoDBfSh2oMDQ',
#   'review_count': 961,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 34.1069829190952,
#    'longitude': -118.263623872353},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '2742 Rowena Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Los Angeles',
#    'zip_code': '90039',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['2742 Rowena Ave', 'Los Angeles, CA 90039']},
#   'phone': '+13236604843',
#   'display_phone': '(323) 660-4843',
#   'distance': 3333.3433281229954},
#  {'id': 'ArwvKXMv027t4boQiSqvhQ',
#   'alias': 'dal-milanese-los-angeles',
#   'name': 'Dal Milanese',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OZcLjIgRSRQEtmWVZhTIiQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/dal-milanese-los-angeles?adjust_creative=mXw-LHOZWkYoDBfSh2oMDQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=mXw-LHOZWkYoDBfSh2oMDQ',
#   'review_count': 98,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 34.109437, 'longitude': -118.287155},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$$',
#   'location': {'address1': '2064 Hillhurst Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Los Angeles',
#    'zip_code': '90027',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['2064 Hillhurst Ave', 'Los Angeles, CA 90027']},
#   'phone': '+13233726002',
#   'display_phone': '(323) 372-6002',
#   'distance': 2108.104110841312},
#  {'id': 'DU3r_rd4wKXxQfAaqHLRYg',
#   'alias': 'farfalla-trattoria-los-angeles',
#   'name': 'Farfalla Trattoria',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/MO0LHtoJ36nk_8FN5_5TKA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/farfalla-trattoria-los-angeles?adjust_creative=mXw-LHOZWkYoDBfSh2oMDQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=mXw-LHOZWkYoDBfSh2oMDQ',
#   'review_count': 756,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 34.1074686, 'longitude': -118.2872751},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1978 Hillhurst Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Los Angeles',
#    'zip_code': '90027',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1978 Hillhurst Ave', 'Los Angeles, CA 90027']},
#   'phone': '+13236617365',
#   'display_phone': '(323) 661-7365',
#   'distance': 2310.600182567731},
#  {'id': 'WPe9r4_b_ByxM-c3OhbDew',
#   'alias': 'il-capriccio-on-vermont-los-angeles',
#   'name': 'Il Capriccio on Vermont',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lXWn8RBszV1S8OXh7nJ6xg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/il-capriccio-on-vermont-los-angeles?adjust_creative=mXw-LHOZWkYoDBfSh2oMDQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=mXw-LHOZWkYoDBfSh2oMDQ',
#   'review_count': 1076,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 34.103042, 'longitude': -118.291857},
#   'transactions': ['restaurant_reservation', 'pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1757 N Vermont Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Los Angeles',
#    'zip_code': '90027',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1757 N Vermont Ave', 'Los Angeles, CA 90027']},
#   'phone': '+13236625900',
#   'display_phone': '(323) 662-5900',
#   'distance': 2817.590529042189},
#  {'id': 'T96uMQQ3xEnT0wmWxCfwww',
#   'alias': 'la-bella-pinseria-romana-glendale',
#   'name': 'La Bella Pinseria Romana',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/c38RneQkdG1Sy9IykFnNew/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/la-bella-pinseria-romana-glendale?adjust_creative=mXw-LHOZWkYoDBfSh2oMDQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=mXw-LHOZWkYoDBfSh2oMDQ',
#   'review_count': 362,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 34.1503167, 'longitude': -118.2580848},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '309 N Central Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Glendale',
#    'zip_code': '91203',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['309 N Central Ave', 'Glendale, CA 91203']},
#   'phone': '+18186468599',
#   'display_phone': '(818) 646-8599',
#   'distance': 3780.399177837355},
#  {'id': 'XN31yqCpt4_aOJDoceuCvw',
#   'alias': 'allacqua-los-angeles-2',
#   'name': "All'Acqua",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6ukUGHnvuBkSHFWIoZWMFg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/allacqua-los-angeles-2?adjust_creative=mXw-LHOZWkYoDBfSh2oMDQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=mXw-LHOZWkYoDBfSh2oMDQ',
#   'review_count': 707,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 34.1184299, 'longitude': -118.25971},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '3280 Glendale Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Los Angeles',
#    'zip_code': '90039',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['3280 Glendale Blvd', 'Los Angeles, CA 90039']},
#   'phone': '+13236633280',
#   'display_phone': '(323) 663-3280',
#   'distance': 2915.574006557854},
#  {'id': '88kri8FhXy8b3DQ_QjSMmQ',
#   'alias': 'l-antica-pizzeria-da-michele-los-angeles-2',
#   'name': "L'Antica Pizzeria Da Michele",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SCuuHjFSwNpuYxpncVDs9w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/l-antica-pizzeria-da-michele-los-angeles-2?adjust_creative=mXw-LHOZWkYoDBfSh2oMDQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=mXw-LHOZWkYoDBfSh2oMDQ',
#   'review_count': 2111,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 34.09906082844746,
#    'longitude': -118.3373093612014},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$$',
#   'location': {'address1': '1534 N Mccadden Pl',
#    'address2': '',
#    'address3': None,
#    'city': 'Los Angeles',
#    'zip_code': '90028',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1534 N Mccadden Pl', 'Los Angeles, CA 90028']},
#   'phone': '+13233662408',
#   'display_phone': '(323) 366-2408',
#   'distance': 5499.65605576803},
#  {'id': 'D3VUJE1Ye4qFWiypiavtOw',
#   'alias': 'mas-italian-kitchen-burbank-2',
#   'name': "MA'S Italian Kitchen",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dK5n3_9T5pq_Qx-DNmk8Hw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mas-italian-kitchen-burbank-2?adjust_creative=mXw-LHOZWkYoDBfSh2oMDQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=mXw-LHOZWkYoDBfSh2oMDQ',
#   'review_count': 1284,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'pastashops', 'title': 'Pasta Shops'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 34.1548299, 'longitude': -118.34559},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '267 North Pass Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Burbank',
#    'zip_code': '91505',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['267 North Pass Ave', 'Burbank, CA 91505']},
#   'phone': '+18185672288',
#   'display_phone': '(818) 567-2288',
#   'distance': 5992.624150565156},
#  {'id': 'EYbE21-tQAt84Yfz8CMlBQ',
#   'alias': 'trattoria-amici-glendale-2',
#   'name': 'Trattoria Amici',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/9uWFHqAs031JNgjnZrPHwg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/trattoria-amici-glendale-2?adjust_creative=mXw-LHOZWkYoDBfSh2oMDQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=mXw-LHOZWkYoDBfSh2oMDQ',
#   'review_count': 1790,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 34.1436429198616,
#    'longitude': -118.256382755119},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '889 Americana Way',
#    'address2': '',
#    'address3': '',
#    'city': 'Glendale',
#    'zip_code': '91210',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['889 Americana Way', 'Glendale, CA 91210']},
#   'phone': '+18185021220',
#   'display_phone': '(818) 502-1220',
#   'distance': 3462.733215192552},
#  {'id': '7By_rryuWeuhx9IDFB1rTw',
#   'alias': 'donnas-los-angeles',
#   'name': "Donna's",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Q0RGfiUyGZdd4Zi-DRvMug/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/donnas-los-angeles?adjust_creative=mXw-LHOZWkYoDBfSh2oMDQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=mXw-LHOZWkYoDBfSh2oMDQ',
#   'review_count': 140,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 34.07619, 'longitude': -118.25656},
#   'transactions': [],
#   'price': '$$$',
#   'location': {'address1': '1538 Sunset Blvd',
#    'address2': None,
#    'address3': '',
#    'city': 'Los Angeles',
#    'zip_code': '90026',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1538 Sunset Blvd', 'Los Angeles, CA 90026']},
#   'phone': '+12132668132',
#   'display_phone': '(213) 266-8132',
#   'distance': 6506.154766090748},
#  {'id': 'F2W1R7yIvSOqD1xH_F1cZA',
#   'alias': 'wood-los-angeles-8',
#   'name': 'Wood',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/3m2BSYYss3odo0nwu8RGJw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/wood-los-angeles-8?adjust_creative=mXw-LHOZWkYoDBfSh2oMDQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=mXw-LHOZWkYoDBfSh2oMDQ',
#   'review_count': 1097,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 34.08292, 'longitude': -118.27289},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$$',
#   'location': {'address1': '2861 Sunset Blvd',
#    'address2': None,
#    'address3': '',
#    'city': 'Los Angeles',
#    'zip_code': '90026',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['2861 Sunset Blvd', 'Los Angeles, CA 90026']},
#   'phone': '+13236679940',
#   'display_phone': '(323) 667-9940',
#   'distance': 5256.2174741791305},
#  {'id': '-gZdC8aD42jiBeaAQH1-1g',
#   'alias': 'lolo-los-angeles-3',
#   'name': 'Lolo',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/RZt0xuSFzuNfFSfKwvCNmQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lolo-los-angeles-3?adjust_creative=mXw-LHOZWkYoDBfSh2oMDQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=mXw-LHOZWkYoDBfSh2oMDQ',
#   'review_count': 120,
#   'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#    {'alias': 'newamerican', 'title': 'New American'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 34.09787, 'longitude': -118.30203},
#   'transactions': ['delivery'],
#   'location': {'address1': '5140 W Sunset Blvd',
#    'address2': None,
#    'address3': '',
#    'city': 'Los Angeles',
#    'zip_code': '90027',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['5140 W Sunset Blvd', 'Los Angeles, CA 90027']},
#   'phone': '+13236655656',
#   'display_phone': '(323) 665-5656',
#   'distance': 3605.571317789698},
#  {'id': 'gd6PYDx-leOM97a3MWoO1g',
#   'alias': 'maccheroni-republic-los-angeles',
#   'name': 'Maccheroni Republic',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zQyc9sFi34wqNturcqnePg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/maccheroni-republic-los-angeles?adjust_creative=mXw-LHOZWkYoDBfSh2oMDQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=mXw-LHOZWkYoDBfSh2oMDQ',
#   'review_count': 4007,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 34.0500282776566,
#    'longitude': -118.24852800000085},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '332 S Broadway',
#    'address2': '',
#    'address3': '',
#    'city': 'Los Angeles',
#    'zip_code': '90013',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['332 S Broadway', 'Los Angeles, CA 90013']},
#   'phone': '+12133469725',
#   'display_phone': '(213) 346-9725',
#   'distance': 9469.590268802514},
#  {'id': 'gAb-NtuNbNG8p2dqUMQGjw',
#   'alias': 'palermo-italian-restaurant-los-angeles-2',
#   'name': 'Palermo Italian Restaurant',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/m1xgemC36RST9oQPS7hrvA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/palermo-italian-restaurant-los-angeles-2?adjust_creative=mXw-LHOZWkYoDBfSh2oMDQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=mXw-LHOZWkYoDBfSh2oMDQ',
#   'review_count': 1785,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 34.10481, 'longitude': -118.291447},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1858 N Vermont Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Los Angeles',
#    'zip_code': '90027',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1858 N Vermont Ave', 'Los Angeles, CA 90027']},
#   'phone': '+13236631430',
#   'display_phone': '(323) 663-1430',
#   'distance': 2618.4784888264094},
#  {'id': 'X_QoHd32bFtUXOilyit44A',
#   'alias': 'speranza-los-angeles',
#   'name': 'Speranza',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lt6VU816lNiDYK_zVSnCqg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/speranza-los-angeles?adjust_creative=mXw-LHOZWkYoDBfSh2oMDQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=mXw-LHOZWkYoDBfSh2oMDQ',
#   'review_count': 653,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 34.105764, 'longitude': -118.273017},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '2547 Hyperion Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Los Angeles',
#    'zip_code': '90027',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['2547 Hyperion Ave', 'Los Angeles, CA 90027']},
#   'phone': '+13236441918',
#   'display_phone': '(323) 644-1918',
#   'distance': 2908.950089165366},
#  {'id': 'rr-hXB0ZqXLzUP97yftp0g',
#   'alias': 'osteria-mamma-los-angeles',
#   'name': 'Osteria Mamma',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/63LCQaMxrDU3QRLYqSJT4g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/osteria-mamma-los-angeles?adjust_creative=mXw-LHOZWkYoDBfSh2oMDQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=mXw-LHOZWkYoDBfSh2oMDQ',
#   'review_count': 1939,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 34.0833586783984,
#    'longitude': -118.324724939274},
#   'transactions': ['restaurant_reservation', 'pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '5732 Melrose Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Los Angeles',
#    'zip_code': '90038',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['5732 Melrose Ave', 'Los Angeles, CA 90038']},
#   'phone': '+13232847060',
#   'display_phone': '(323) 284-7060',
#   'distance': 5975.127660785935},
#  {'id': 'PK9bwd-vOUNFM7ef68rN8g',
#   'alias': 'blairs-restaurant-los-angeles',
#   'name': "Blair's Restaurant",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/9P2Ci3BL3T1ioKWH4afHgA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/blairs-restaurant-los-angeles?adjust_creative=mXw-LHOZWkYoDBfSh2oMDQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=mXw-LHOZWkYoDBfSh2oMDQ',
#   'review_count': 610,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 34.10851, 'longitude': -118.26806},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '2903 Rowena Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Los Angeles',
#    'zip_code': '90039',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['2903 Rowena Ave', 'Los Angeles, CA 90039']},
#   'phone': '+13236601882',
#   'display_phone': '(323) 660-1882',
#   'distance': 2924.167405393401},
#  {'id': 'GKQApReu8U9hip4A2ApJ_A',
#   'alias': 'osteria-la-buca-los-angeles-2',
#   'name': 'Osteria La Buca',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/xeVaSq6kS6WuT3OFj7yPJg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/osteria-la-buca-los-angeles-2?adjust_creative=mXw-LHOZWkYoDBfSh2oMDQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=mXw-LHOZWkYoDBfSh2oMDQ',
#   'review_count': 2283,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 34.0833366755519, 'longitude': -118.31393718099},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '5210 Melrose Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Los Angeles',
#    'zip_code': '90038',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['5210 Melrose Ave', 'Los Angeles, CA 90038']},
#   'phone': '+13234621900',
#   'display_phone': '(323) 462-1900',
#   'distance': 5495.3705973891665}]

# %%
pd.DataFrame(results['businesses'])
# Out:
#                         id                                       alias  \
# 0   -KqNRM-drDM7Nu9i9xEnfA                 la-pergoletta-los-angeles-4
# 1   IMvn6wIq4YvJ9Mk5rqdX8g                           spina-los-angeles
# 2   WylKsZv1qKCDqrHd-joiOA       michelangelo-ristorante-los-angeles-2
# 3   ArwvKXMv027t4boQiSqvhQ                    dal-milanese-los-angeles
# 4   DU3r_rd4wKXxQfAaqHLRYg              farfalla-trattoria-los-angeles
# 5   WPe9r4_b_ByxM-c3OhbDew         il-capriccio-on-vermont-los-angeles
# 6   T96uMQQ3xEnT0wmWxCfwww           la-bella-pinseria-romana-glendale
# 7   XN31yqCpt4_aOJDoceuCvw                      allacqua-los-angeles-2
# 8   88kri8FhXy8b3DQ_QjSMmQ  l-antica-pizzeria-da-michele-los-angeles-2
# 9   D3VUJE1Ye4qFWiypiavtOw               mas-italian-kitchen-burbank-2
# 10  EYbE21-tQAt84Yfz8CMlBQ                  trattoria-amici-glendale-2
# 11  7By_rryuWeuhx9IDFB1rTw                          donnas-los-angeles
# 12  F2W1R7yIvSOqD1xH_F1cZA                          wood-los-angeles-8
# 13  -gZdC8aD42jiBeaAQH1-1g                          lolo-los-angeles-3
# 14  gd6PYDx-leOM97a3MWoO1g             maccheroni-republic-los-angeles
# 15  gAb-NtuNbNG8p2dqUMQGjw    palermo-italian-restaurant-los-angeles-2
# 16  X_QoHd32bFtUXOilyit44A                        speranza-los-angeles
# 17  rr-hXB0ZqXLzUP97yftp0g                   osteria-mamma-los-angeles
# 18  PK9bwd-vOUNFM7ef68rN8g               blairs-restaurant-los-angeles
# 19  GKQApReu8U9hip4A2ApJ_A               osteria-la-buca-los-angeles-2
#
#                             name  \
# 0                  La Pergoletta
# 1                          Spina
# 2        Michelangelo Ristorante
# 3                   Dal Milanese
# 4             Farfalla Trattoria
# 5        Il Capriccio on Vermont
# 6       La Bella Pinseria Romana
# 7                      All'Acqua
# 8   L'Antica Pizzeria Da Michele
# 9           MA'S Italian Kitchen
# 10               Trattoria Amici
# 11                       Donna's
# 12                          Wood
# 13                          Lolo
# 14           Maccheroni Republic
# 15    Palermo Italian Restaurant
# 16                      Speranza
# 17                 Osteria Mamma
# 18            Blair's Restaurant
# 19               Osteria La Buca
#
#                                             image_url  is_closed  \
# 0   https://s3-media3.fl.yelpcdn.com/bphoto/G1XjeB...      False
# 1   https://s3-media2.fl.yelpcdn.com/bphoto/GO39QC...      False
# 2   https://s3-media2.fl.yelpcdn.com/bphoto/ZRopJJ...      False
# 3   https://s3-media2.fl.yelpcdn.com/bphoto/OZcLjI...      False
# 4   https://s3-media1.fl.yelpcdn.com/bphoto/MO0LHt...      False
# 5   https://s3-media2.fl.yelpcdn.com/bphoto/lXWn8R...      False
# 6   https://s3-media3.fl.yelpcdn.com/bphoto/c38Rne...      False
# 7   https://s3-media3.fl.yelpcdn.com/bphoto/6ukUGH...      False
# 8   https://s3-media2.fl.yelpcdn.com/bphoto/SCuuHj...      False
# 9   https://s3-media2.fl.yelpcdn.com/bphoto/dK5n3_...      False
# 10  https://s3-media4.fl.yelpcdn.com/bphoto/9uWFHq...      False
# 11  https://s3-media4.fl.yelpcdn.com/bphoto/Q0RGfi...      False
# 12  https://s3-media4.fl.yelpcdn.com/bphoto/3m2BSY...      False
# 13  https://s3-media4.fl.yelpcdn.com/bphoto/RZt0xu...      False
# 14  https://s3-media3.fl.yelpcdn.com/bphoto/zQyc9s...      False
# 15  https://s3-media2.fl.yelpcdn.com/bphoto/m1xgem...      False
# 16  https://s3-media2.fl.yelpcdn.com/bphoto/lt6VU8...      False
# 17  https://s3-media2.fl.yelpcdn.com/bphoto/63LCQa...      False
# 18  https://s3-media4.fl.yelpcdn.com/bphoto/9P2Ci3...      False
# 19  https://s3-media3.fl.yelpcdn.com/bphoto/xeVaSq...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/la-pergoletta-los-ang...          1346
# 1   https://www.yelp.com/biz/spina-los-angeles?adj...            13
# 2   https://www.yelp.com/biz/michelangelo-ristoran...           961
# 3   https://www.yelp.com/biz/dal-milanese-los-ange...            98
# 4   https://www.yelp.com/biz/farfalla-trattoria-lo...           756
# 5   https://www.yelp.com/biz/il-capriccio-on-vermo...          1076
# 6   https://www.yelp.com/biz/la-bella-pinseria-rom...           362
# 7   https://www.yelp.com/biz/allacqua-los-angeles-...           707
# 8   https://www.yelp.com/biz/l-antica-pizzeria-da-...          2111
# 9   https://www.yelp.com/biz/mas-italian-kitchen-b...          1284
# 10  https://www.yelp.com/biz/trattoria-amici-glend...          1790
# 11  https://www.yelp.com/biz/donnas-los-angeles?ad...           140
# 12  https://www.yelp.com/biz/wood-los-angeles-8?ad...          1097
# 13  https://www.yelp.com/biz/lolo-los-angeles-3?ad...           120
# 14  https://www.yelp.com/biz/maccheroni-republic-l...          4007
# 15  https://www.yelp.com/biz/palermo-italian-resta...          1785
# 16  https://www.yelp.com/biz/speranza-los-angeles?...           653
# 17  https://www.yelp.com/biz/osteria-mamma-los-ang...          1939
# 18  https://www.yelp.com/biz/blairs-restaurant-los...           610
# 19  https://www.yelp.com/biz/osteria-la-buca-los-a...          2283
#
#                                            categories  rating  \
# 0          [{'alias': 'italian', 'title': 'Italian'}]     4.5
# 1   [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.5
# 2   [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.5
# 3          [{'alias': 'italian', 'title': 'Italian'}]     4.5
# 4          [{'alias': 'italian', 'title': 'Italian'}]     4.0
# 5   [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.0
# 6   [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.5
# 7   [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.0
# 8   [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 9   [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.5
# 10         [{'alias': 'italian', 'title': 'Italian'}]     4.0
# 11         [{'alias': 'italian', 'title': 'Italian'}]     4.5
# 12  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 13  [{'alias': 'wine_bars', 'title': 'Wine Bars'},...     4.0
# 14  [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.5
# 15  [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.0
# 16         [{'alias': 'italian', 'title': 'Italian'}]     4.0
# 17  [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.0
# 18  [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.0
# 19  [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.0
#
#                                           coordinates  \
# 0   {'latitude': 34.1037812, 'longitude': -118.287...
# 1     {'latitude': 34.11792, 'longitude': -118.26131}
# 2   {'latitude': 34.1069829190952, 'longitude': -1...
# 3   {'latitude': 34.109437, 'longitude': -118.287155}
# 4   {'latitude': 34.1074686, 'longitude': -118.287...
# 5   {'latitude': 34.103042, 'longitude': -118.291857}
# 6   {'latitude': 34.1503167, 'longitude': -118.258...
# 7   {'latitude': 34.1184299, 'longitude': -118.25971}
# 8   {'latitude': 34.09906082844746, 'longitude': -...
# 9   {'latitude': 34.1548299, 'longitude': -118.34559}
# 10  {'latitude': 34.1436429198616, 'longitude': -1...
# 11    {'latitude': 34.07619, 'longitude': -118.25656}
# 12    {'latitude': 34.08292, 'longitude': -118.27289}
# 13    {'latitude': 34.09787, 'longitude': -118.30203}
# 14  {'latitude': 34.0500282776566, 'longitude': -1...
# 15   {'latitude': 34.10481, 'longitude': -118.291447}
# 16  {'latitude': 34.105764, 'longitude': -118.273017}
# 17  {'latitude': 34.0833586783984, 'longitude': -1...
# 18    {'latitude': 34.10851, 'longitude': -118.26806}
# 19  {'latitude': 34.0833366755519, 'longitude': -1...
#
#                                   transactions price  \
# 0   [restaurant_reservation, pickup, delivery]    $$
# 1                                           []   NaN
# 2                           [pickup, delivery]    $$
# 3                           [pickup, delivery]   $$$
# 4                           [pickup, delivery]    $$
# 5   [restaurant_reservation, pickup, delivery]    $$
# 6                           [pickup, delivery]    $$
# 7                           [pickup, delivery]    $$
# 8                           [pickup, delivery]   $$$
# 9                           [pickup, delivery]    $$
# 10                          [pickup, delivery]    $$
# 11                                          []   $$$
# 12                          [pickup, delivery]   $$$
# 13                                  [delivery]   NaN
# 14                          [pickup, delivery]    $$
# 15                          [pickup, delivery]    $$
# 16                          [pickup, delivery]    $$
# 17  [restaurant_reservation, pickup, delivery]    $$
# 18                          [pickup, delivery]    $$
# 19                          [pickup, delivery]    $$
#
#                                              location         phone  \
# 0   {'address1': '1802 Hillhurst Ave', 'address2':...  +13236648259
# 1   {'address1': '3193 Glendale Blvd', 'address2':...
# 2   {'address1': '2742 Rowena Ave', 'address2': ''...  +13236604843
# 3   {'address1': '2064 Hillhurst Ave', 'address2':...  +13233726002
# 4   {'address1': '1978 Hillhurst Ave', 'address2':...  +13236617365
# 5   {'address1': '1757 N Vermont Ave', 'address2':...  +13236625900
# 6   {'address1': '309 N Central Ave', 'address2': ...  +18186468599
# 7   {'address1': '3280 Glendale Blvd', 'address2':...  +13236633280
# 8   {'address1': '1534 N Mccadden Pl', 'address2':...  +13233662408
# 9   {'address1': '267 North Pass Ave', 'address2':...  +18185672288
# 10  {'address1': '889 Americana Way', 'address2': ...  +18185021220
# 11  {'address1': '1538 Sunset Blvd', 'address2': N...  +12132668132
# 12  {'address1': '2861 Sunset Blvd', 'address2': N...  +13236679940
# 13  {'address1': '5140 W Sunset Blvd', 'address2':...  +13236655656
# 14  {'address1': '332 S Broadway', 'address2': '',...  +12133469725
# 15  {'address1': '1858 N Vermont Ave', 'address2':...  +13236631430
# 16  {'address1': '2547 Hyperion Ave', 'address2': ...  +13236441918
# 17  {'address1': '5732 Melrose Ave', 'address2': '...  +13232847060
# 18  {'address1': '2903 Rowena Ave', 'address2': No...  +13236601882
# 19  {'address1': '5210 Melrose Ave', 'address2': '...  +13234621900
#
#      display_phone     distance
# 0   (323) 664-8259  2730.591010
# 1                   2803.730389
# 2   (323) 660-4843  3333.343328
# 3   (323) 372-6002  2108.104111
# 4   (323) 661-7365  2310.600183
# 5   (323) 662-5900  2817.590529
# 6   (818) 646-8599  3780.399178
# 7   (323) 663-3280  2915.574007
# 8   (323) 366-2408  5499.656056
# 9   (818) 567-2288  5992.624151
# 10  (818) 502-1220  3462.733215
# 11  (213) 266-8132  6506.154766
# 12  (323) 667-9940  5256.217474
# 13  (323) 665-5656  3605.571318
# 14  (213) 346-9725  9469.590269
# 15  (323) 663-1430  2618.478489
# 16  (323) 644-1918  2908.950089
# 17  (323) 284-7060  5975.127661
# 18  (323) 660-1882  2924.167405
# 19  (323) 462-1900  5495.370597

# %%
results_per_page = len(results['businesses'])
results_per_page
# Out:
# 20

# %%
(results['total'])/results_per_page
# Out:
# 55.0

# %%
n_pages = math.ceil((results['total'])/results_per_page)
n_pages
# Out:
# 55

# %%
for i in tqdm_notebook(range(1,n_pages+1)):
    try:
        time.sleep(.2)
        with open(JSON_FILE, 'r') as f:
            previous_results = json.load(f)
        n_results = len(previous_results)
        results = yelp.search_query(location=location, term=term, offset=n_results+1)
        previous_results.extend(results['businesses'])
        with open(JSON_FILE, 'w') as f:
            json.dump(previous_results, f)
    except Exception as e:
        print(' [!] ERROR', e)
# Out:
#   0%|          | 0/55 [00:00<?, ?it/s]
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981
#  [!] ERROR 400 Client Error: Bad Request for url: https://api.yelp.com/v3/businesses/search?location=Los+Angeles%2C+CA+90027&term=italian&offset=981

# %%
df = pd.read_json(JSON_FILE)
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980 entries, 0 to 979
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             980 non-null    object
#  1   alias          980 non-null    object
#  2   name           980 non-null    object
#  3   image_url      980 non-null    object
#  4   is_closed      980 non-null    bool
#  5   url            980 non-null    object
#  6   review_count   980 non-null    int64
#  7   categories     980 non-null    object
#  8   rating         980 non-null    float64
#  9   coordinates    980 non-null    object
#  10  transactions   980 non-null    object
#  11  location       980 non-null    object
#  12  phone          980 non-null    object
#  13  display_phone  980 non-null    object
#  14  distance       980 non-null    float64
#  15  price          816 non-null    object
# dtypes: bool(1), float64(2), int64(1), object(12)
# memory usage: 115.9+ KB
#                        id                                  alias  \
# 0  IMvn6wIq4YvJ9Mk5rqdX8g                      spina-los-angeles
# 1  WylKsZv1qKCDqrHd-joiOA  michelangelo-ristorante-los-angeles-2
# 2  ArwvKXMv027t4boQiSqvhQ               dal-milanese-los-angeles
# 3  DU3r_rd4wKXxQfAaqHLRYg         farfalla-trattoria-los-angeles
# 4  WPe9r4_b_ByxM-c3OhbDew    il-capriccio-on-vermont-los-angeles
#
#                       name                                          image_url  \
# 0                    Spina  https://s3-media2.fl.yelpcdn.com/bphoto/GO39QC...
# 1  Michelangelo Ristorante  https://s3-media2.fl.yelpcdn.com/bphoto/ZRopJJ...
# 2             Dal Milanese  https://s3-media2.fl.yelpcdn.com/bphoto/OZcLjI...
# 3       Farfalla Trattoria  https://s3-media1.fl.yelpcdn.com/bphoto/MO0LHt...
# 4  Il Capriccio on Vermont  https://s3-media2.fl.yelpcdn.com/bphoto/lXWn8R...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/spina-los-angeles?adj...            13
# 1      False  https://www.yelp.com/biz/michelangelo-ristoran...           961
# 2      False  https://www.yelp.com/biz/dal-milanese-los-ange...            98
# 3      False  https://www.yelp.com/biz/farfalla-trattoria-lo...           756
# 4      False  https://www.yelp.com/biz/il-capriccio-on-vermo...          1076
#
#                                           categories  rating  \
# 0  [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.5
# 1  [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.5
# 2         [{'alias': 'italian', 'title': 'Italian'}]     4.5
# 3         [{'alias': 'italian', 'title': 'Italian'}]     4.0
# 4  [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.0
#
#                                          coordinates  \
# 0    {'latitude': 34.11792, 'longitude': -118.26131}
# 1  {'latitude': 34.1069829190952, 'longitude': -1...
# 2  {'latitude': 34.109437, 'longitude': -118.287155}
# 3  {'latitude': 34.1074686, 'longitude': -118.287...
# 4  {'latitude': 34.103042, 'longitude': -118.291857}
#
#                                  transactions  \
# 0                                          []
# 1                          [pickup, delivery]
# 2                          [pickup, delivery]
# 3                          [pickup, delivery]
# 4  [restaurant_reservation, pickup, delivery]
#
#                                             location         phone  \
# 0  {'address1': '3193 Glendale Blvd', 'address2':...
# 1  {'address1': '2742 Rowena Ave', 'address2': ''...  +13236604843
# 2  {'address1': '2064 Hillhurst Ave', 'address2':...  +13233726002
# 3  {'address1': '1978 Hillhurst Ave', 'address2':...  +13236617365
# 4  {'address1': '1757 N Vermont Ave', 'address2':...  +13236625900
#
#     display_phone     distance price
# 0                  2803.730389   NaN
# 1  (323) 660-4843  3333.343328    $$
# 2  (323) 372-6002  2108.104111   $$$
# 3  (323) 661-7365  2310.600183    $$
# 4  (323) 662-5900  2817.590529    $$

# %%
csv_file = JSON_FILE.replace('.json', '.csv.gz')
csv_file
# Out:
# 'Data/Los Angeles-italian.csv.gz'

# %%
df.to_csv(csv_file, compression='gzip', index=False)
